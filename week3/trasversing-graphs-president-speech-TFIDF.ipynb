# %%
import requests
stop_url = "https://gist.githubusercontent.com/rg089/35e00abf8941d72d419224cfd5b5925d/raw/12d899b70156fd0041fa9778d657330b024b959c/stopwords.txt"
stopwords_list = requests.get(stop_url).content
stopwords = set(stopwords_list.decode().splitlines())
stopwords = list(stopwords)


def remove_stopwords(low): # low = list of words
    list_ = re.sub(r"[^a-zA-Z0-9]", " ", low.lower()).split()
    return [itm for itm in list_ if itm not in stopwords]

# %%
from collections import Counter
import glob
import re

# %%
import numpy as np
def calculate_tf_idf(speech_dir):
    """Calculate TF-IDF for speeches in directory"""
    
    # Read all txt files
    speeches = []
    for filepath in glob.glob(f"{speech_dir}/*.txt"):
        with open(filepath, 'r', encoding='utf-8') as f:
            speeches.append(f.read())

    # Process each speech
    processed_speeches = []
    for speech in speeches:
        filtered_bow = remove_stopwords(speech)
        processed_speeches.append(filtered_bow)
    
    # Calculate document frequencies
    doc_freq = Counter()
    for speech in processed_speeches:
        unique_words = set(speech) # unique for each speech
        for word in unique_words:
            doc_freq[word] += 1
    
    # Calculate IDFs
    N = len(speeches) #total number of documents
    idfs = {}
    for word, df in doc_freq.items(): # df : document frequency
        idfs[word] = np.log((N + 1)/(df + 1)) + 1
    
    tf_idf_scores = []
    # Calculate TF for all speeches combined
    for i, speech in enumerate(processed_speeches):
        # Calculate TF for this document
        doc_length = len(speech)
        word_counts = Counter(speech)
        
        # Calculate TF-IDF for each word in this document
        for word, count in word_counts.items():
            tf = count/doc_length
            tf_idf = tf * idfs[word]
            tf_idf_scores.append((f"{word}_doc{i}", tf_idf))
    
    # Get top 15 words
    top_words = sorted(tf_idf_scores, 
                      key=lambda x: x[1], 
                      reverse=True)[:15]
    
    return top_words

# Example usage
directory = "/Users/yi.hs/cs119/cs-119-bigdata/week3/prez_speeches/kennedy"  # directory with extracted txt files
top_words = calculate_tf_idf(directory)
print("Top 15 most important words:")
for word, score in top_words:
    print(f"{word}: {score:.4f}")
# Out:
# Top 15 most important words:
# corps_doc30: 0.1177
# catholic_doc41: 0.1051
# tax_doc26: 0.0977
# religious_doc41: 0.0927
# mississippi_doc7: 0.0905
# berlin_doc3: 0.0814
# peace_doc30: 0.0786
# university_doc35: 0.0777
# united_doc8: 0.0760
# uh_doc44: 0.0633
# vanderbilt_doc23: 0.0619
# frost_doc0: 0.0618
# church_doc41: 0.0618
# city_doc3: 0.0605
# nuclear_doc4: 0.0586

# %%
import os
os.chdir('/Users/yi.hs/cs119/cs-119-bigdata/week3/prez_speeches')

def list_president_files():
    # Assuming we're in the directory containing president folders
    for president_dir in glob.glob("*/"):
        print(f"\nFiles for {president_dir}:")
        for txt_file in glob.glob(f"{president_dir}/*.txt"):
            print(txt_file)

# Example usage
list_president_files()
# Out:
# Files for coolidge/:
# coolidge/coolidge_speeches_009.txt
# coolidge/coolidge_speeches_008.txt
# coolidge/coolidge_speeches_000.txt
# coolidge/coolidge_speeches_001.txt
# coolidge/coolidge_speeches_003.txt
# coolidge/coolidge_speeches_002.txt
# roosevelt/roosevelt_speeches_007.txt
# roosevelt/roosevelt_speeches_013.txt
# roosevelt/roosevelt_speeches_012.txt
# roosevelt/roosevelt_speeches_006.txt
# roosevelt/roosevelt_speeches_010.txt
# roosevelt/roosevelt_speeches_004.txt
# roosevelt/roosevelt_speeches_005.txt
# roosevelt/roosevelt_speeches_011.txt
#
# Files for eisenhower/:
# eisenhower/eisenhower_speeches_002.txt
# eisenhower/eisenhower_speeches_003.txt
# eisenhower/eisenhower_speeches_001.txt
# eisenhower/eisenhower_speeches_000.txt
# eisenhower/eisenhower_speeches_004.txt
# eisenhower/eisenhower_speeches_005.txt
#
# Files for buchanan/:
# buchanan/buchanan_speeches_002.txt
# buchanan/buchanan_speeches_003.txt
# buchanan/buchanan_speeches_001.txt
# buchanan/buchanan_speeches_000.txt
# buchanan/buchanan_speeches_004.txt
# buchanan/buchanan_speeches_010.txt
# buchanan/buchanan_speeches_011.txt
# buchanan/buchanan_speeches_005.txt
# buchanan/buchanan_speeches_013.txt
# buchanan/buchanan_speeches_007.txt
# buchanan/buchanan_speeches_006.txt
# buchanan/buchanan_speeches_012.txt
# buchanan/buchanan_speeches_008.txt
# buchanan/buchanan_speeches_009.txt
#
# Files for lbjohnson/:
# lbjohnson/lbjohnson_speeches_070.txt
# lbjohnson/lbjohnson_speeches_064.txt
# lbjohnson/lbjohnson_speeches_058.txt
# lbjohnson/lbjohnson_speeches_059.txt
# lbjohnson/lbjohnson_speeches_065.txt
# lbjohnson/lbjohnson_speeches_067.txt
# lbjohnson/lbjohnson_speeches_066.txt
# lbjohnson/lbjohnson_speeches_062.txt
# lbjohnson/lbjohnson_speeches_063.txt
# lbjohnson/lbjohnson_speeches_049.txt
# lbjohnson/lbjohnson_speeches_061.txt
# lbjohnson/lbjohnson_speeches_060.txt
# lbjohnson/lbjohnson_speeches_048.txt
# lbjohnson/lbjohnson_speeches_013.txt
# lbjohnson/lbjohnson_speeches_007.txt
# lbjohnson/lbjohnson_speeches_006.txt
# lbjohnson/lbjohnson_speeches_012.txt
# lbjohnson/lbjohnson_speeches_004.txt
# lbjohnson/lbjohnson_speeches_010.txt
# lbjohnson/lbjohnson_speeches_038.txt
# lbjohnson/lbjohnson_speeches_039.txt
# lbjohnson/lbjohnson_speeches_011.txt
# lbjohnson/lbjohnson_speeches_005.txt
# lbjohnson/lbjohnson_speeches_029.txt
# lbjohnson/lbjohnson_speeches_001.txt
# lbjohnson/lbjohnson_speeches_015.txt
# lbjohnson/lbjohnson_speeches_014.txt
# lbjohnson/lbjohnson_speeches_000.txt
# lbjohnson/lbjohnson_speeches_028.txt
# lbjohnson/lbjohnson_speeches_016.txt
# lbjohnson/lbjohnson_speeches_002.txt
# lbjohnson/lbjohnson_speeches_003.txt
# lbjohnson/lbjohnson_speeches_017.txt
# lbjohnson/lbjohnson_speeches_032.txt
# lbjohnson/lbjohnson_speeches_026.txt
# lbjohnson/lbjohnson_speeches_027.txt
# lbjohnson/lbjohnson_speeches_033.txt
# lbjohnson/lbjohnson_speeches_025.txt
# lbjohnson/lbjohnson_speeches_031.txt
# lbjohnson/lbjohnson_speeches_019.txt
# lbjohnson/lbjohnson_speeches_018.txt
# lbjohnson/lbjohnson_speeches_030.txt
# lbjohnson/lbjohnson_speeches_024.txt
# lbjohnson/lbjohnson_speeches_008.txt
# lbjohnson/lbjohnson_speeches_020.txt
# lbjohnson/lbjohnson_speeches_034.txt
# lbjohnson/lbjohnson_speeches_035.txt
# lbjohnson/lbjohnson_speeches_021.txt
# lbjohnson/lbjohnson_speeches_009.txt
# lbjohnson/lbjohnson_speeches_037.txt
# lbjohnson/lbjohnson_speeches_023.txt
# lbjohnson/lbjohnson_speeches_022.txt
# lbjohnson/lbjohnson_speeches_036.txt
# lbjohnson/lbjohnson_speeches_051.txt
# lbjohnson/lbjohnson_speeches_045.txt
# lbjohnson/lbjohnson_speeches_044.txt
# lbjohnson/lbjohnson_speeches_050.txt
# lbjohnson/lbjohnson_speeches_046.txt
# lbjohnson/lbjohnson_speeches_052.txt
# lbjohnson/lbjohnson_speeches_053.txt
# lbjohnson/lbjohnson_speeches_047.txt
# lbjohnson/lbjohnson_speeches_043.txt
# lbjohnson/lbjohnson_speeches_057.txt
# lbjohnson/lbjohnson_speeches_056.txt
# lbjohnson/lbjohnson_speeches_042.txt
# lbjohnson/lbjohnson_speeches_068.txt
# lbjohnson/lbjohnson_speeches_054.txt
# lbjohnson/lbjohnson_speeches_040.txt
# lbjohnson/lbjohnson_speeches_041.txt
# lbjohnson/lbjohnson_speeches_055.txt
# lbjohnson/lbjohnson_speeches_069.txt
#
# Files for adams/:
# adams/adams_speeches_008.txt
# adams/adams_speeches_001.txt
# adams/adams_speeches_000.txt
# adams/adams_speeches_002.txt
# adams/adams_speeches_003.txt
# adams/adams_speeches_007.txt
# adams/adams_speeches_006.txt
# adams/adams_speeches_004.txt
# adams/adams_speeches_005.txt
#
# Files for arthur/:
# arthur/arthur_speeches_002.txt
# arthur/arthur_speeches_003.txt
# arthur/arthur_speeches_001.txt
# arthur/arthur_speeches_000.txt
# arthur/arthur_speeches_004.txt
# arthur/arthur_speeches_010.txt
# arthur/arthur_speeches_005.txt
# arthur/arthur_speeches_007.txt
# arthur/arthur_speeches_006.txt
# arthur/arthur_speeches_008.txt
# arthur/arthur_speeches_009.txt
#
# Files for fillmore/:
# fillmore/fillmore_speeches_006.txt
# fillmore/fillmore_speeches_005.txt
# fillmore/fillmore_speeches_004.txt
# fillmore/fillmore_speeches_000.txt
# fillmore/fillmore_speeches_001.txt
# fillmore/fillmore_speeches_003.txt
# fillmore/fillmore_speeches_002.txt
#
# Files for kennedy/:
# kennedy/kennedy_speeches_044.txt
# kennedy/kennedy_speeches_043.txt
# kennedy/kennedy_speeches_042.txt
# kennedy/kennedy_speeches_040.txt
# kennedy/kennedy_speeches_041.txt
# kennedy/kennedy_speeches_026.txt
# kennedy/kennedy_speeches_032.txt
# kennedy/kennedy_speeches_033.txt
# truman/truman_speeches_010.txt
# truman/truman_speeches_004.txt
# truman/truman_speeches_005.txt
# truman/truman_speeches_011.txt
# truman/truman_speeches_007.txt
# truman/truman_speeches_013.txt
# truman/truman_speeches_012.txt
# truman/truman_speeches_006.txt
# truman/truman_speeches_008.txt
# truman/truman_speeches_009.txt
# truman/truman_speeches_018.txt
#
# Files for gwbush/:
# gwbush/gwbush_speeches_037.txt
# gwbush/gwbush_speeches_023.txt
# gwbush/gwbush_speeches_022.txt
# gwbush/gwbush_speeches_036.txt
# gwbush/gwbush_speeches_020.txt
# gwbush/gwbush_speeches_034.txt
# gwbush/gwbush_speeches_008.txt
# gwbush/gwbush_speeches_009.txt
# gwbush/gwbush_speeches_035.txt
# gwbush/gwbush_speeches_021.txt
# gwbush/gwbush_speeches_019.txt
# gwbush/gwbush_speeches_025.txt
# gwbush/gwbush_speeches_031.txt
# gwbush/gwbush_speeches_030.txt
# gwbush/gwbush_speeches_024.txt
# gwbush/gwbush_speeches_018.txt
# gwbush/gwbush_speeches_032.txt
# gwbush/gwbush_speeches_026.txt
# gwbush/gwbush_speeches_027.txt
# gwbush/gwbush_speeches_033.txt
# gwbush/gwbush_speeches_016.txt
# gwbush/gwbush_speeches_002.txt
# gwbush/gwbush_speeches_003.txt
# gwbush/gwbush_speeches_017.txt
# gwbush/gwbush_speeches_001.txt
# gwbush/gwbush_speeches_015.txt
# gwbush/gwbush_speeches_029.txt
# gwbush/gwbush_speeches_028.txt
# gwbush/gwbush_speeches_014.txt
# gwbush/gwbush_speeches_000.txt
# gwbush/gwbush_speeches_038.txt
# gwbush/gwbush_speeches_004.txt
# gwbush/gwbush_speeches_010.txt
# gwbush/gwbush_speeches_011.txt
# gwbush/gwbush_speeches_005.txt
# gwbush/gwbush_speeches_013.txt
# gwbush/gwbush_speeches_007.txt
# gwbush/gwbush_speeches_006.txt
# gwbush/gwbush_speeches_012.txt
#
# Files for garfield/:
# garfield/garfield_speeches_000.txt
#
# Files for harding/:
# harding/harding_speeches_011.txt
# harding/harding_speeches_005.txt
# harding/harding_speeches_004.txt
# harding/harding_speeches_010.txt
# harding/harding_speeches_006.txt
# harding/harding_speeches_012.txt
# harding/harding_speeches_013.txt
# harding/harding_speeches_007.txt
# harding/harding_speeches_003.txt
# harding/harding_speeches_017.txt
# harding/harding_speeches_016.txt
# harding/harding_speeches_002.txt
# harding/harding_speeches_014.txt
# harding/harding_speeches_000.txt
# harding/harding_speeches_001.txt
# harding/harding_speeches_015.txt
# harding/harding_speeches_009.txt
# harding/harding_speeches_008.txt
#
# Files for mckinley/:
# mckinley/mckinley_speeches_008.txt
# mckinley/mckinley_speeches_009.txt
# mckinley/mckinley_speeches_010.txt
# mckinley/mckinley_speeches_004.txt
# mckinley/mckinley_speeches_005.txt
# mckinley/mckinley_speeches_011.txt
# mckinley/mckinley_speeches_007.txt
# mckinley/mckinley_speeches_013.txt
# mckinley/mckinley_speeches_012.txt
# mckinley/mckinley_speeches_006.txt
# mckinley/mckinley_speeches_002.txt
# mckinley/mckinley_speeches_003.txt
# mckinley/mckinley_speeches_001.txt
# mckinley/mckinley_speeches_000.txt
#
# Files for vanburen/:
# vanburen/vanburen_speeches_008.txt
# vanburen/vanburen_speeches_009.txt
# vanburen/vanburen_speeches_001.txt
# vanburen/vanburen_speeches_000.txt
# vanburen/vanburen_speeches_002.txt
# vanburen/vanburen_speeches_003.txt
# vanburen/vanburen_speeches_007.txt
# vanburen/vanburen_speeches_006.txt
# vanburen/vanburen_speeches_004.txt
# vanburen/vanburen_speeches_005.txt
#
# Files for polk/:
# polk/polk_speeches_005.txt
# polk/polk_speeches_011.txt
# polk/polk_speeches_010.txt
# polk/polk_speeches_004.txt
# polk/polk_speeches_012.txt
# polk/polk_speeches_006.txt
# polk/polk_speeches_007.txt
# polk/polk_speeches_013.txt
# polk/polk_speeches_017.txt
# polk/polk_speeches_003.txt
# polk/polk_speeches_002.txt
# polk/polk_speeches_016.txt
# polk/polk_speeches_000.txt
# polk/polk_speeches_014.txt
# polk/polk_speeches_015.txt
# polk/polk_speeches_001.txt
# polk/polk_speeches_024.txt
# polk/polk_speeches_018.txt
# polk/polk_speeches_019.txt
# polk/polk_speeches_022.txt
# polk/polk_speeches_023.txt
# polk/polk_speeches_009.txt
# polk/polk_speeches_021.txt
# polk/polk_speeches_020.txt
# polk/polk_speeches_008.txt
#
# Files for grant/:
# grant/grant_speeches_008.txt
# grant/grant_speeches_020.txt
# grant/grant_speeches_021.txt
# grant/grant_speeches_009.txt
# grant/grant_speeches_023.txt
# grant/grant_speeches_022.txt
# grant/grant_speeches_026.txt
# grant/grant_speeches_027.txt
# grant/grant_speeches_031.txt
# grant/grant_speeches_025.txt
# grant/grant_speeches_019.txt
# grant/grant_speeches_018.txt
# grant/grant_speeches_024.txt
# grant/grant_speeches_030.txt
# grant/grant_speeches_029.txt
# grant/grant_speeches_015.txt
# grant/grant_speeches_001.txt
# grant/grant_speeches_000.txt
# grant/grant_speeches_014.txt
# grant/grant_speeches_028.txt
# grant/grant_speeches_002.txt
# grant/grant_speeches_016.txt
# grant/grant_speeches_017.txt
# grant/grant_speeches_003.txt
# grant/grant_speeches_007.txt
# grant/grant_speeches_013.txt
# grant/grant_speeches_012.txt
# grant/grant_speeches_006.txt
# grant/grant_speeches_010.txt
# grant/grant_speeches_004.txt
# grant/grant_speeches_005.txt
# grant/grant_speeches_011.txt
#
# Files for jqadams/:
# jqadams/jqadams_speeches_000.txt
# jqadams/jqadams_speeches_001.txt
# jqadams/jqadams_speeches_003.txt
# jqadams/jqadams_speeches_002.txt
# jqadams/jqadams_speeches_006.txt
# jqadams/jqadams_speeches_007.txt
# jqadams/jqadams_speeches_005.txt
# jqadams/jqadams_speeches_004.txt
#
# Files for jackson/:
# jackson/jackson_speeches_023.txt
# jackson/jackson_speeches_022.txt
# jackson/jackson_speeches_008.txt
# jackson/jackson_speeches_020.txt
# jackson/jackson_speeches_021.txt
# jackson/jackson_speeches_009.txt
# jackson/jackson_speeches_025.txt
# jackson/jackson_speeches_019.txt
# jackson/jackson_speeches_018.txt
# jackson/jackson_speeches_024.txt
# jackson/jackson_speeches_002.txt
# jackson/jackson_speeches_016.txt
# jackson/jackson_speeches_017.txt
# jackson/jackson_speeches_003.txt
# jackson/jackson_speeches_015.txt
# jackson/jackson_speeches_001.txt
# jackson/jackson_speeches_000.txt
# jackson/jackson_speeches_014.txt
# jackson/jackson_speeches_010.txt
# jackson/jackson_speeches_004.txt
# jackson/jackson_speeches_005.txt
# jackson/jackson_speeches_011.txt
# jackson/jackson_speeches_007.txt
# jackson/jackson_speeches_013.txt
# jackson/jackson_speeches_012.txt
# jackson/jackson_speeches_006.txt

# %%
import numpy as np
from collections import Counter
import glob
import re
import requests
import os

def calculate_president_tfidf(target_president):
    # Dictionary to store all speeches for each president
    president_speeches = {}
    
    # Read all speeches for each president
    for president_dir in os.listdir('.'):
        if os.path.isdir(president_dir):
            all_speeches = []
            for filepath in glob.glob(f"{president_dir}/*.txt"):
                with open(filepath, 'r', encoding='utf-8') as f:
                    speech = f.read()
                    filtered_speech = remove_stopwords(speech)
                    all_speeches.extend(filtered_speech)
            president_speeches[president_dir] = all_speeches
    
    # Check if target president exists
    if target_president not in president_speeches:
        raise ValueError(f"President {target_president} not found in directory")
    
    # Calculate document frequencies
    doc_freq = Counter()
    for president, speeches in president_speeches.items():
        unique_words = set(speeches)
        for word in unique_words:
            doc_freq[word] += 1
    
    # Calculate IDFs
    N = len(president_speeches)
    idfs = {}
    for word, df in doc_freq.items():
        idfs[word] = np.log((N + 1)/(df + 1)) + 1
    
    # Calculate TF-IDF for target president
    speeches = president_speeches[target_president]
    total_words = len(speeches)
    word_counts = Counter(speeches)
    
    # Calculate TF-IDF scores
    tfidf_scores = {}
    for word, count in word_counts.items():
        tf = count/total_words
        tfidf_scores[word] = tf * idfs[word]
    
    # Get top 15 words
    top_words = sorted(tfidf_scores.items(), 
                      key=lambda x: x[1], 
                      reverse=True)[:15]
    
    return top_words

# %%
top_words_kennedy = calculate_president_tfidf("kennedy")

# %%
print(f"\nTop 15 words for Kennedy:")
for word, score in top_words_kennedy:
    print(f"{word}: {score:.4f}")
# Out:
# Top 15 words for Kennedy:
# uh: 0.0115
# kennedy: 0.0093
# united: 0.0080
# states: 0.0069
# people: 0.0062
# president: 0.0062
# nuclear: 0.0061
# nixon: 0.0060
# country: 0.0059
# senator: 0.0054
# today: 0.0053
# economic: 0.0051
# freedom: 0.0050
# soviet: 0.0049
# years: 0.0049

# %%
top_words_hoover = calculate_president_tfidf("hoover")

print(f"\nTop 15 words for hoover:")
for word, score in top_words_hoover:
    print(f"{word}: {score:.4f}")
# Out:
# Top 15 words for hoover:
# government: 0.0120
# 000: 0.0103
# people: 0.0080
# economic: 0.0076
# federal: 0.0066
# american: 0.0064
# states: 0.0059
# business: 0.0055
# country: 0.0052
# public: 0.0052
# tariff: 0.0050
# congress: 0.0049
# democratic: 0.0048
# great: 0.0047
# national: 0.0044
